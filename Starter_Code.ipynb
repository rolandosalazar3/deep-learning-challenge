# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
dropapplication_df = application_df.drop(['EIN', 'NAME'], axis=1)

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
dropapplication_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
application_counts = dropapplication_df['APPLICATION_TYPE'].value_counts()
application_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = list(application_counts[application_counts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
dropapplication_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
class_count = dropapplication_df['CLASSIFICATION'].value_counts()
class_count[class_count > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = list(class_count[class_count < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
convert_to_numeric_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
X = convert_to_numeric_df.drop("IS_SUCCESSFUL", axis=1).values
y = convert_to_numeric_df["IS_SUCCESSFUL"].values

# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 34)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
x = X_train_scaled.shape[1]
nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=80, activation='relu', input_dim= x))

# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=30, activation='relu'))

# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                1569040
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 1,571,501
# Trainable params: 1,571,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Create a callback that saves the model's weights every five epochs
# Import dependencies
#import os
#from tensorflow.keras.callbacks import ModelCheckpoint

# Checkpoint variables
#os.makedirs('Callback/', exist_ok=True)
#checkpoint_path= 'Callback/weight.{epoch}.hdf5'

# Create callback 
#cp_callback = ModelCheckpoint(filepath=checkpoint_path, verbose=1, save_weights_only=True, save_freq='epoch', period=5)

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled,y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 13s 15ms/step - loss: 0.4963 - accuracy: 0.7547
# Epoch 2/100
# 804/804 [==============================] - 12s 15ms/step - loss: 0.1358 - accuracy: 0.9507
# Epoch 3/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0974 - accuracy: 0.9608
# Epoch 4/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0934 - accuracy: 0.9614
# Epoch 5/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0926 - accuracy: 0.9624
# Epoch 6/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0912 - accuracy: 0.9626
# Epoch 7/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0906 - accuracy: 0.9626
# Epoch 8/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0899 - accuracy: 0.9625
# Epoch 9/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0891 - accuracy: 0.9624
# Epoch 10/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0882 - accuracy: 0.9630
# Epoch 11/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0871 - accuracy: 0.9631
# Epoch 12/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0865 - accuracy: 0.9634
# Epoch 13/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0859 - accuracy: 0.9643
# Epoch 14/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0861 - accuracy: 0.9640
# Epoch 15/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0851 - accuracy: 0.9643
# Epoch 16/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0845 - accuracy: 0.9649
# Epoch 17/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0845 - accuracy: 0.9644
# Epoch 18/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0841 - accuracy: 0.9651
# Epoch 19/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0835 - accuracy: 0.9655
# Epoch 20/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0827 - accuracy: 0.9655
# Epoch 21/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0825 - accuracy: 0.9659
# Epoch 22/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0817 - accuracy: 0.9656
# Epoch 23/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0820 - accuracy: 0.9662
# Epoch 24/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0809 - accuracy: 0.9665
# Epoch 25/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0808 - accuracy: 0.9668
# Epoch 26/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0803 - accuracy: 0.9669
# Epoch 27/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0801 - accuracy: 0.9670
# Epoch 28/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0796 - accuracy: 0.9675
# Epoch 29/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0793 - accuracy: 0.9672
# Epoch 30/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0788 - accuracy: 0.9675
# Epoch 31/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0785 - accuracy: 0.9676
# Epoch 32/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0781 - accuracy: 0.9680
# Epoch 33/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0775 - accuracy: 0.9680
# Epoch 34/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0772 - accuracy: 0.9678
# Epoch 35/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0771 - accuracy: 0.9680
# Epoch 36/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0769 - accuracy: 0.9680
# Epoch 37/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0765 - accuracy: 0.9682
# Epoch 38/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0762 - accuracy: 0.9689
# Epoch 39/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0760 - accuracy: 0.9689
# Epoch 40/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0756 - accuracy: 0.9687
# Epoch 41/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0751 - accuracy: 0.9691
# Epoch 42/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0747 - accuracy: 0.9690
# Epoch 43/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0747 - accuracy: 0.9689
# Epoch 44/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0746 - accuracy: 0.9693
# Epoch 45/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0743 - accuracy: 0.9692
# Epoch 46/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0739 - accuracy: 0.9696
# Epoch 47/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0740 - accuracy: 0.9691
# Epoch 48/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0738 - accuracy: 0.9697
# Epoch 49/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0739 - accuracy: 0.9693
# Epoch 50/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0734 - accuracy: 0.9696
# Epoch 51/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0731 - accuracy: 0.9703
# Epoch 52/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0733 - accuracy: 0.9697
# Epoch 53/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0730 - accuracy: 0.9697
# Epoch 54/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0728 - accuracy: 0.9700
# Epoch 55/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0726 - accuracy: 0.9706
# Epoch 56/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0722 - accuracy: 0.9702
# Epoch 57/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0724 - accuracy: 0.9703
# Epoch 58/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0720 - accuracy: 0.9705
# Epoch 59/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0722 - accuracy: 0.9706
# Epoch 60/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0719 - accuracy: 0.9705
# Epoch 61/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0719 - accuracy: 0.9706
# Epoch 62/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0718 - accuracy: 0.9713
# Epoch 63/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0715 - accuracy: 0.9706
# Epoch 64/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0714 - accuracy: 0.9704
# Epoch 65/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0715 - accuracy: 0.9706
# Epoch 66/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0707 - accuracy: 0.9711
# Epoch 67/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0710 - accuracy: 0.9713
# Epoch 68/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0712 - accuracy: 0.9710
# Epoch 69/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0705 - accuracy: 0.9716
# Epoch 70/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0706 - accuracy: 0.9713
# Epoch 71/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0704 - accuracy: 0.9713
# Epoch 72/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0703 - accuracy: 0.9716
# Epoch 73/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0703 - accuracy: 0.9708
# Epoch 74/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0703 - accuracy: 0.9712
# Epoch 75/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0707 - accuracy: 0.9713
# Epoch 76/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0699 - accuracy: 0.9714
# Epoch 77/100
# 804/804 [==============================] - 12s 14ms/step - loss: 0.0697 - accuracy: 0.9716
# Epoch 78/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0694 - accuracy: 0.9713
# Epoch 79/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0695 - accuracy: 0.9718
# Epoch 80/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0696 - accuracy: 0.9713
# Epoch 81/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0697 - accuracy: 0.9713
# Epoch 82/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0693 - accuracy: 0.9719
# Epoch 83/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0700 - accuracy: 0.9715
# Epoch 84/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0688 - accuracy: 0.9713
# Epoch 85/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0693 - accuracy: 0.9717
# Epoch 86/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0691 - accuracy: 0.9717
# Epoch 87/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0683 - accuracy: 0.9721
# Epoch 88/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0686 - accuracy: 0.9713
# Epoch 89/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0697 - accuracy: 0.9719
# Epoch 90/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0708 - accuracy: 0.9706
# Epoch 91/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0688 - accuracy: 0.9722
# Epoch 92/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0680 - accuracy: 0.9719
# Epoch 93/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0679 - accuracy: 0.9722
# Epoch 94/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0682 - accuracy: 0.9725
# Epoch 95/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0677 - accuracy: 0.9720
# Epoch 96/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0677 - accuracy: 0.9723
# Epoch 97/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0673 - accuracy: 0.9724
# Epoch 98/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0679 - accuracy: 0.9721
# Epoch 99/100
# 804/804 [==============================] - 11s 13ms/step - loss: 0.0680 - accuracy: 0.9722
# Epoch 100/100
# 804/804 [==============================] - 11s 14ms/step - loss: 0.0679 - accuracy: 0.9718

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.9235 - accuracy: 0.6983 - 1s/epoch - 5ms/step
# Loss: 0.923451840877533, Accuracy: 0.698309063911438

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save('checkpoint/AlphabetSoupCharity.h5')
